# %% [markdown]
# # 🦷 MAHT-Net Environment Test
#
# This notebook tests the MAHT-Net project environment to ensure all dependencies and functionality are working correctly.
#
# **Project:** Multi-Stage Attention-enhanced Hybrid Transformer Network for Cephalometric Landmark Detection
# **Institution:** Konya Technical University
# **Researcher:** Mohamed Nourdine
#
# ---

# %% [markdown]
# ## 1. Import Required Libraries
# Let's import essential Python libraries to verify they are properly installed:

# %%
# Import essential libraries for MAHT-Net
import sys
import os
import platform
from datetime import datetime

# Scientific computing libraries
try:
    import numpy as np
    print("✅ NumPy imported successfully")
except ImportError as e:
    print(f"❌ NumPy import failed: {e}")

try:
    import pandas as pd
    print("✅ Pandas imported successfully")
except ImportError as e:
    print(f"❌ Pandas import failed: {e}")

try:
    import matplotlib.pyplot as plt
    print("✅ Matplotlib imported successfully")
except ImportError as e:
    print(f"❌ Matplotlib import failed: {e}")

# Deep learning libraries (may not be installed yet)
try:
    import torch
    print(f"✅ PyTorch imported successfully (version: {torch.__version__})")
except ImportError as e:
    print(f"⚠️ PyTorch not installed yet: {e}")

print(f"\n🐍 Python version: {sys.version}")
print(f"📅 Test run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# ✅ NumPy imported successfully
# ✅ Pandas imported successfully
# ✅ Pandas imported successfully
# ✅ Matplotlib imported successfully
# ⚠️ PyTorch not installed yet: No module named 'torch'
#
# 🐍 Python version: 3.9.23 (main, Jun  5 2025, 13:40:20)
# [GCC 11.2.0]
# 📅 Test run on: 2025-07-22 23:37:46
# ✅ Matplotlib imported successfully
# ⚠️ PyTorch not installed yet: No module named 'torch'
#
# 🐍 Python version: 3.9.23 (main, Jun  5 2025, 13:40:20)
# [GCC 11.2.0]
# 📅 Test run on: 2025-07-22 23:37:46

# %% [markdown]
# ## 2. Test Basic Python Operations
# Testing fundamental Python operations to ensure the interpreter is working correctly:

# %%
# Test basic arithmetic operations
print("🧮 Arithmetic Operations:")
a, b = 10, 3
print(f"  {a} + {b} = {a + b}")
print(f"  {a} * {b} = {a * b}")
print(f"  {a} / {b} = {a / b:.2f}")
print(f"  {a} ** {b} = {a ** b}")

# Test string operations
print("\n📝 String Operations:")
text = "MAHT-Net"
print(f"  Original: '{text}'")
print(f"  Uppercase: '{text.upper()}'")
print(f"  Length: {len(text)}")
print(f"  Reversed: '{text[::-1]}'")

# Test list operations
print("\n📋 List Operations:")
numbers = [1, 2, 3, 4, 5]
print(f"  Original list: {numbers}")
print(f"  Sum: {sum(numbers)}")
print(f"  Max: {max(numbers)}")
print(f"  Squared: {[x**2 for x in numbers]}")

# Test dictionary operations
print("\n🗂️ Dictionary Operations:")
project_info = {
    'name': 'MAHT-Net',
    'university': 'Konya Technical University',
    'researcher': 'Mohamed Nourdine',
    'year': 2025
}
print(f"  Project: {project_info['name']}")
print(f"  Keys: {list(project_info.keys())}")
print(f"  Values: {list(project_info.values())}")

print("\n✅ All basic Python operations are working correctly!")
# Out:
# 🧮 Arithmetic Operations:
#   10 + 3 = 13
#   10 * 3 = 30
#   10 / 3 = 3.33
#   10 ** 3 = 1000
#
# 📝 String Operations:
#   Original: 'MAHT-Net'
#   Uppercase: 'MAHT-NET'
#   Length: 8
#   Reversed: 'teN-THAM'
#
# 📋 List Operations:
#   Original list: [1, 2, 3, 4, 5]
#   Sum: 15
#   Max: 5
#   Squared: [1, 4, 9, 16, 25]
#
# 🗂️ Dictionary Operations:
#   Project: MAHT-Net
#   Keys: ['name', 'university', 'researcher', 'year']
#   Values: ['MAHT-Net', 'Konya Technical University', 'Mohamed Nourdine', 2025]
#
# ✅ All basic Python operations are working correctly!

# %% [markdown]
# ## 3. Test NumPy Functionality
# Testing NumPy operations essential for scientific computing in MAHT-Net:

# %%
if 'np' in globals():
    print("🔢 NumPy Array Operations:")
    
    # Create arrays
    arr1 = np.array([1, 2, 3, 4, 5])
    arr2 = np.array([10, 20, 30, 40, 50])
    
    print(f"  Array 1: {arr1}")
    print(f"  Array 2: {arr2}")
    print(f"  Shape of Array 1: {arr1.shape}")
    print(f"  Data type: {arr1.dtype}")
    
    # Mathematical operations
    print(f"\n➕ Array Addition: {arr1 + arr2}")
    print(f"✖️ Array Multiplication: {arr1 * arr2}")
    print(f"📊 Array Mean: {np.mean(arr1):.2f}")
    print(f"📈 Array Standard Deviation: {np.std(arr1):.2f}")
    
    # 2D array operations (important for image processing)
    print(f"\n🖼️ 2D Array Operations:")
    matrix = np.random.rand(3, 3)
    print(f"  Random 3x3 matrix:\n{matrix}")
    print(f"  Matrix shape: {matrix.shape}")
    print(f"  Matrix sum: {np.sum(matrix):.2f}")
    
    # Linear algebra operations (crucial for deep learning)
    print(f"\n🧮 Linear Algebra:")
    vector_a = np.array([1, 2, 3])
    vector_b = np.array([4, 5, 6])
    dot_product = np.dot(vector_a, vector_b)
    print(f"  Vector A: {vector_a}")
    print(f"  Vector B: {vector_b}")
    print(f"  Dot Product: {dot_product}")
    
    print(f"\n✅ NumPy is working correctly! Version: {np.__version__}")
else:
    print("❌ NumPy not available - please install numpy first")
# Out:
# 🔢 NumPy Array Operations:
#   Array 1: [1 2 3 4 5]
#   Array 2: [10 20 30 40 50]
#   Shape of Array 1: (5,)
#   Data type: int64
#
# ➕ Array Addition: [11 22 33 44 55]
# ✖️ Array Multiplication: [ 10  40  90 160 250]
# 📊 Array Mean: 3.00
# 📈 Array Standard Deviation: 1.41
#
# 🖼️ 2D Array Operations:
#   Random 3x3 matrix:
# [[0.75554902 0.64674203 0.9157211 ]
#  [0.91496958 0.68232787 0.62283229]
#  [0.99144644 0.00840518 0.45570156]]
#   Matrix shape: (3, 3)
#   Matrix sum: 5.99
#
# 🧮 Linear Algebra:
#   Vector A: [1 2 3]
#   Vector B: [4 5 6]
#   Dot Product: 32
#
# ✅ NumPy is working correctly! Version: 2.0.1

# %% [markdown]
# ## 4. Test Matplotlib Visualization
# Testing plotting capabilities essential for data visualization and result analysis:

# %%
if 'plt' in globals() and 'np' in globals():
    print("📊 Testing Matplotlib Visualization:")
    
    # Set up the plotting area
    plt.figure(figsize=(12, 8))
    
    # Create sample data
    x = np.linspace(0, 10, 100)
    y1 = np.sin(x)
    y2 = np.cos(x)
    
    # Subplot 1: Line plot
    plt.subplot(2, 2, 1)
    plt.plot(x, y1, 'b-', label='sin(x)', linewidth=2)
    plt.plot(x, y2, 'r--', label='cos(x)', linewidth=2)
    plt.title('Trigonometric Functions')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Subplot 2: Scatter plot
    plt.subplot(2, 2, 2)
    x_scatter = np.random.randn(50)
    y_scatter = 2 * x_scatter + np.random.randn(50)
    plt.scatter(x_scatter, y_scatter, alpha=0.6, c='purple')
    plt.title('Random Scatter Plot')
    plt.xlabel('X values')
    plt.ylabel('Y values')
    plt.grid(True, alpha=0.3)
    
    # Subplot 3: Histogram
    plt.subplot(2, 2, 3)
    data = np.random.normal(0, 1, 1000)
    plt.hist(data, bins=30, alpha=0.7, color='green', edgecolor='black')
    plt.title('Normal Distribution Histogram')
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.grid(True, alpha=0.3)
    
    # Subplot 4: Simple bar chart
    plt.subplot(2, 2, 4)
    categories = ['Training', 'Validation', 'Testing']
    values = [0.85, 0.78, 0.82]
    colors = ['#FF6B6B', '#4ECDC4', '#45B7D1']
    plt.bar(categories, values, color=colors, alpha=0.8)
    plt.title('Model Performance')
    plt.ylabel('Accuracy')
    plt.ylim(0, 1)
    plt.grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.suptitle('🦷 MAHT-Net Visualization Test', fontsize=16, y=1.02)
    plt.show()
    
    print("✅ Matplotlib is working correctly!")
    print(f"   Version: {plt.matplotlib.__version__}")
    
else:
    print("❌ Matplotlib or NumPy not available - plotting functionality disabled")
# Out:
# 📊 Testing Matplotlib Visualization:
# ✅ Matplotlib is working correctly!
#    Version: 3.9.2

# %% [markdown]
# ## 5. Environment Information Check
# Displaying comprehensive system and environment information:

# %%
print("🖥️ System Information:")
print(f"  Platform: {platform.platform()}")
print(f"  Architecture: {platform.architecture()}")
print(f"  Machine: {platform.machine()}")
print(f"  Processor: {platform.processor()}")
print(f"  Python Implementation: {platform.python_implementation()}")

print(f"\n🐍 Python Environment:")
print(f"  Python Version: {sys.version}")
print(f"  Python Executable: {sys.executable}")
print(f"  Python Path: {sys.path[0]}")

print(f"\n📁 Current Working Directory:")
print(f"  CWD: {os.getcwd()}")

print(f"\n🌍 Environment Variables (selected):")
env_vars = ['PATH', 'HOME', 'USER', 'CONDA_DEFAULT_ENV', 'CONDA_PREFIX']
for var in env_vars:
    value = os.environ.get(var, 'Not set')
    if var == 'PATH':
        # Truncate PATH for readability
        value = value[:100] + '...' if len(value) > 100 else value
    print(f"  {var}: {value}")

print(f"\n📦 Package Versions:")
packages_to_check = ['numpy', 'pandas', 'matplotlib', 'torch', 'torchvision']
for package in packages_to_check:
    try:
        module = __import__(package)
        version = getattr(module, '__version__', 'Unknown')
        print(f"  ✅ {package}: {version}")
    except ImportError:
        print(f"  ❌ {package}: Not installed")

# Check if we're in conda environment
conda_env = os.environ.get('CONDA_DEFAULT_ENV', 'Not in conda environment')
print(f"\n🅰️ Conda Environment:")
print(f"  Active Environment: {conda_env}")

print(f"\n💾 Memory Information:")
try:
    import psutil
    memory = psutil.virtual_memory()
    print(f"  Total Memory: {memory.total / (1024**3):.2f} GB")
    print(f"  Available Memory: {memory.available / (1024**3):.2f} GB")
    print(f"  Memory Usage: {memory.percent}%")
except ImportError:
    print("  psutil not available - install for memory info")

print(f"\n✅ Environment check complete!")
# Out:
# 🖥️ System Information:
#   Platform: Linux-6.8.0-1031-aws-x86_64-with-glibc2.35
#   Architecture: ('64bit', 'ELF')
#   Machine: x86_64
#   Processor: x86_64
#   Python Implementation: CPython
#
# 🐍 Python Environment:
#   Python Version: 3.9.23 (main, Jun  5 2025, 13:40:20)
# [GCC 11.2.0]
#   Python Executable: /home/ubuntu/miniconda3/envs/maht-net/bin/python
#   Python Path: /home/ubuntu/miniconda3/envs/maht-net/lib/python39.zip
#
# 📁 Current Working Directory:
#   CWD: /home/ubuntu/maht-net/notebooks
#
# 🌍 Environment Variables (selected):
#   PATH: /home/ubuntu/miniconda3/envs/maht-net/bin:/home/ubuntu/.vscode-server/cli/servers/Stable-7adae6a56e3...
#   HOME: /home/ubuntu
#   USER: ubuntu
#   CONDA_DEFAULT_ENV: maht-net
#   CONDA_PREFIX: /home/ubuntu/miniconda3/envs/maht-net
#
# 📦 Package Versions:
#   ✅ numpy: 2.0.1
#   ✅ pandas: 2.3.1
#   ✅ matplotlib: 3.9.2
#   ✅ torch: 2.5.1
#   ✅ torchvision: 0.20.1
#
# 🅰️ Conda Environment:
#   Active Environment: maht-net
#
# ...

# %% [markdown]
# ## 6. Test File System Operations
# Testing file I/O operations essential for data processing and model saving:

# %%
import tempfile
import shutil

print("📁 File System Operations Test:")

# Create a temporary directory for testing
test_dir = tempfile.mkdtemp(prefix='maht_net_test_')
print(f"  Created temporary directory: {test_dir}")

try:
    # Test file writing
    test_file = os.path.join(test_dir, 'test_file.txt')
    with open(test_file, 'w') as f:
        f.write("MAHT-Net Environment Test\n")
        f.write("Konya Technical University\n")
        f.write("Mohamed Nourdine - PhD Research\n")
    print(f"  ✅ File writing successful: {test_file}")
    
    # Test file reading
    with open(test_file, 'r') as f:
        content = f.read()
    print(f"  ✅ File reading successful")
    print(f"  File content preview: {content.split()[0:3]}...")
    
    # Test file size and permissions
    file_size = os.path.getsize(test_file)
    file_permissions = oct(os.stat(test_file).st_mode)[-3:]
    print(f"  File size: {file_size} bytes")
    print(f"  File permissions: {file_permissions}")
    
    # Test directory operations
    sub_dir = os.path.join(test_dir, 'subdirectory')
    os.makedirs(sub_dir, exist_ok=True)
    print(f"  ✅ Directory creation successful: {sub_dir}")
    
    # Test file listing
    files_in_dir = os.listdir(test_dir)
    print(f"  Directory contents: {files_in_dir}")
    
    # Test CSV file operations (important for datasets)
    if 'pd' in globals():
        csv_file = os.path.join(test_dir, 'test_data.csv')
        test_data = {
            'landmark_id': [1, 2, 3, 4, 5],
            'x_coordinate': [100.5, 150.2, 200.8, 75.3, 300.1],
            'y_coordinate': [50.1, 80.7, 120.4, 200.9, 25.6],
            'confidence': [0.95, 0.87, 0.92, 0.78, 0.99]
        }
        df = pd.DataFrame(test_data)
        df.to_csv(csv_file, index=False)
        print(f"  ✅ CSV file created successfully")
        
        # Read CSV back
        df_read = pd.read_csv(csv_file)
        print(f"  ✅ CSV file read successfully - shape: {df_read.shape}")
    
    # Test JSON operations (for configuration files)
    import json
    json_file = os.path.join(test_dir, 'config.json')
    config_data = {
        "project": "MAHT-Net",
        "version": "1.0",
        "author": "Mohamed Nourdine",
        "university": "Konya Technical University",
        "settings": {
            "batch_size": 32,
            "learning_rate": 0.001,
            "epochs": 100
        }
    }
    with open(json_file, 'w') as f:
        json.dump(config_data, f, indent=2)
    print(f"  ✅ JSON file operations successful")
    
    print(f"\n✅ All file system operations completed successfully!")
    
except Exception as e:
    print(f"  ❌ File system operation failed: {e}")

finally:
    # Clean up temporary directory
    try:
        shutil.rmtree(test_dir)
        print(f"  🧹 Cleaned up temporary directory")
    except Exception as e:
        print(f"  ⚠️ Could not clean up temporary directory: {e}")

print(f"\n🎉 MAHT-Net Environment Test Complete!")
print(f"   All essential functionality has been verified.")
print(f"   The environment is ready for MAHT-Net development! 🦷")
# Out:
# 📁 File System Operations Test:
#   Created temporary directory: /tmp/maht_net_test_z9b7n834
#   ✅ File writing successful: /tmp/maht_net_test_z9b7n834/test_file.txt
#   ✅ File reading successful
#   File content preview: ['MAHT-Net', 'Environment', 'Test']...
#   File size: 85 bytes
#   File permissions: 664
#   ✅ Directory creation successful: /tmp/maht_net_test_z9b7n834/subdirectory
#   Directory contents: ['subdirectory', 'test_file.txt']
#   ✅ CSV file created successfully
#   ✅ CSV file read successfully - shape: (5, 4)
#   ✅ JSON file operations successful
#
# ✅ All file system operations completed successfully!
#   🧹 Cleaned up temporary directory
#
# 🎉 MAHT-Net Environment Test Complete!
#    All essential functionality has been verified.
#    The environment is ready for MAHT-Net development! 🦷
